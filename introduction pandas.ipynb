# %% [markdown]
# print("Hello, World!")

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# instructing the compiler to print the text over

# %% [raw]
# prrint()

# %% [markdown]
# # print()

# %% [markdown]
# ###print()

# %%
def greater_num(a, b):
    if a>b:
        return a
    else:
        return b

# %%
greater_num(6,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b783e37809f> in <module>
# ----> 1 greater_num(6,7)
#
# NameError: name 'greater_num' is not defined

# %%
greater_num(6,7)
# Out:
# 7

# %%
greater_num(11,3)
# Out:
# 11

# %%
import pandas as pd

# %% [markdown]
# ser = pd.Series(data=[100, 200, 300, 400,500], index=['tom', 'bob', 'nancy', 'dan', 'eric'])
# pd.series is the function of pandas

# %%
ser
# Out:
# tom      100
# bob      200
# nancy    300
# dan      400
# eric     500
# dtype: int64

# %% [markdown]
# ser

# %%
ser.index
# Out:
# Index(['tom', 'bob', 'nancy', 'dan', 'eric'], dtype='object')

# %%
ser['nancy']
# Out:
# 300

# %%
ser[[4, 3, 1]]
# Out:
# eric    500
# dan     400
# bob     200
# dtype: int64

# %%
'bob' in ser
# Out:
# True

# %%
'bob' in ser
# Out:
# True

# %%
ser[4,3,1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9286528e2696> in <module>
# ----> 1 ser[4,3,1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     904             return self._get_values(key)
#     905
# --> 906         return self._get_with(key)
#     907
#     908     def _get_with(self, key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     919             )
#     920         elif isinstance(key, tuple):
# --> 921             return self._get_values_tuple(key)
#     922
#     923         elif not is_list_like(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_values_tuple(self, key)
#     954
#     955         if not isinstance(self.index, MultiIndex):
# --> 956             raise ValueError("key of type tuple not found and not a MultiIndex")
#     957
#     958         # If key is contained, would have returned by now
#
# ValueError: key of type tuple not found and not a MultiIndex

# %%
ser[4]
# Out:
# 500

# %%
ser * 2
# Out:
# tom       200
# bob       400
# nancy     600
# dan       800
# eric     1000
# dtype: int64

# %%
'rachana' in ser
# Out:
# False

# %%
ser ** 2
# Out:
# tom       10000
# bob       40000
# nancy     90000
# dan      160000
# eric     250000
# dtype: int64

# %%
    d = {'one' : pd.Series([100, 200, 300], index=['apple', 'ball', 'clock']), 'two' : pd.Series([111, 222, 333, 4444], index=['apple', 'ball', 'cerill', 'dancy'])}

# %%
df = pd.Dataframe(d)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e44f29113921> in <module>
# ----> 1 df = pd.DataFrame(d)
#       2 print(df)
#
# NameError: name 'pd' is not defined

# %%
df.index
# Out:
# Index(['apple', 'ball', 'cerill', 'clock', 'dancy'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
pd.DataFrame(d, index=['dancy', 'ball', 'apple'])
# Out:
#          one   two
# dancy    NaN  4444
# ball   200.0   222
# apple  100.0   111

# %%
pd.DataFrame(d, index=['dancy', 'ball', 'apple'], columns=['two', 'five'])
# Out:
#         two five
# dancy  4444  NaN
# ball    222  NaN
# apple   111  NaN

# %%
r=pd.DataFrame(d, index=['dancy', 'ball', 'apple'], columns=['two', 'five'])

# %%
r
# Out:
#         two five
# dancy  4444  NaN
# ball    222  NaN
# apple   111  NaN

# %%
data = [{'alex':1, 'joe':2}, {'ema':5, 'dora':10, 'alice':20}]

# %%
pd.DataFrame(data)
# Out:
#    alex  joe  ema  dora  alice
# 0   1.0  2.0  NaN   NaN    NaN
# 1   NaN  NaN  5.0  10.0   20.0

# %%
pd.DataFrame(data, index=['orange', 'red'])
# Out:
#         alex  joe  ema  dora  alice
# orange   1.0  2.0  NaN   NaN    NaN
# red      NaN  NaN  5.0  10.0   20.0

# %%
pd.DataFrame(data, columns=['joe', 'dora', 'alice'])
# Out:
#    joe  dora  alice
# 0  2.0   NaN    NaN
# 1  NaN  10.0   20.0

# %%
pd.DataFrame(data, columns=['joe', 'ema', 'dora','alice'])
# Out:
#    joe  ema  dora  alice
# 0  2.0  NaN   NaN    NaN
# 1  NaN  5.0  10.0   20.0

# %%
df
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df['one']
# Out:
# apple     100.0
# ball      200.0
# cerill      NaN
# clock     300.0
# dancy       NaN
# Name: one, dtype: float64

# %%
df['three']= df['one']*df['two']
df
# Out:
#           one     two    three
# apple   100.0   111.0  11100.0
# ball    200.0   222.0  44400.0
# cerill    NaN   333.0      NaN
# clock   300.0     NaN      NaN
# dancy     NaN  4444.0      NaN

# %%
# Out:
# apple     11100.0
# ball      44400.0
# cerill        NaN
# clock         NaN
# dancy         NaN
# Name: three, dtype: float64

# %%
df['one']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e408da86a7a6> in <module>
# ----> 1 df['one']
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = pd.DataFrame(d)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e44f29113921> in <module>
# ----> 1 df = pd.DataFrame(d)
#       2 print(df)
#
# NameError: name 'pd' is not defined

# %%
    d = {'one' : pd.Series([100, 200, 300], index=['apple', 'ball', 'clock']), 'two' : pd.Series([111, 222, 333, 4444], index=['apple', 'ball', 'cerill', 'dancy'])}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5571b6b67446> in <module>
# ----> 1 d = {'one' : pd.Series([100, 200, 300], index=['apple', 'ball', 'clock']), 'two' : pd.Series([111, 222, 333, 4444], index=['apple', 'ball', 'cerill', 'dancy'])}
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
    d = {'one' : pd.Series([100, 200, 300], index=['apple', 'ball', 'clock']), 'two' : pd.Series([111, 222, 333, 4444], index=['apple', 'ball', 'cerill', 'dancy'])}

# %%
df = pd.DataFrame(d)
print(df)
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df
# Out:
#           one   flag
# apple   100.0  False
# ball    200.0  False
# cerill    NaN  False
# clock   300.0   True
# dancy     NaN  False

# %%
df['one']
# Out:
# apple     100.0
# ball      200.0
# cerill      NaN
# clock     300.0
# dancy       NaN
# Name: one, dtype: float64

# %%
df['three']= df['one']*df['two']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'two'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-2338bd954a13> in <module>
# ----> 1 df['three']= df['one']*df['two']
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'two'

# %%
df['flag']= df['one']>250
df
# Out:
#           one     two    three   flag
# apple   100.0   111.0  11100.0  False
# ball    200.0   222.0  44400.0  False
# cerill    NaN   333.0      NaN  False
# clock   300.0     NaN      NaN   True
# dancy     NaN  4444.0      NaN  False

# %%
thre= df.pop('three')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'three'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-078a45032cd9> in <module>
# ----> 1 thre= df.pop('three')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    4365         3  monkey        NaN
#    4366         """
# -> 4367         return super().pop(item=item)
#    4368
#    4369     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'three'

# %%
three
# Out:
# apple     11100.0
# ball      44400.0
# cerill        NaN
# clock         NaN
# dancy         NaN
# Name: three, dtype: float64

# %%
three= df.pop('three')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'three'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-eded01250216> in <module>
# ----> 1 three= df.pop('three')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    4365         3  monkey        NaN
#    4366         """
# -> 4367         return super().pop(item=item)
#    4368
#    4369     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'three'

# %%
two
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7bbef45b3bc7> in <module>
# ----> 1 two
#
# NameError: name 'two' is not defined

# %%
three= df.pop('three')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'three'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-eded01250216> in <module>
# ----> 1 three= df.pop('three')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    4365         3  monkey        NaN
#    4366         """
# -> 4367         return super().pop(item=item)
#    4368
#    4369     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'three'

# %%
df['one']
# Out:
# apple     100.0
# ball      200.0
# cerill      NaN
# clock     300.0
# dancy       NaN
# Name: one, dtype: float64

# %%
df['three']=df['one']*df['two']
df
# Out:
#           one     two    three
# apple   100.0   111.0  11100.0
# ball    200.0   222.0  44400.0
# cerill    NaN   333.0      NaN
# clock   300.0     NaN      NaN
# dancy     NaN  4444.0      NaN

# %%
df['flag']= df['one']>250
df
# Out:
#           one     two    three   flag
# apple   100.0   111.0  11100.0  False
# ball    200.0   222.0  44400.0  False
# cerill    NaN   333.0      NaN  False
# clock   300.0     NaN      NaN   True
# dancy     NaN  4444.0      NaN  False

# %%
three= df.pop('three')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'three'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-eded01250216> in <module>
# ----> 1 three= df.pop('three')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pop(self, item)
#    4365         3  monkey        NaN
#    4366         """
# -> 4367         return super().pop(item=item)
#    4368
#    4369     @doc(NDFrame.replace, **_shared_doc_kwargs)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in pop(self, item)
#     659
#     660     def pop(self, item: Label) -> Union["Series", Any]:
# --> 661         result = self[item]
#     662         del self[item]
#     663         if self.ndim == 2:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'three'

# %%
three
# Out:
# apple     11100.0
# ball      44400.0
# cerill        NaN
# clock         NaN
# dancy         NaN
# Name: three, dtype: float64

# %%
df
# Out:
#           one   flag
# apple   100.0  False
# ball    200.0  False
# cerill    NaN  False
# clock   300.0   True
# dancy     NaN  False

# %%
two
# Out:
# apple      111.0
# ball       222.0
# cerill     333.0
# clock        NaN
# dancy     4444.0
# Name: two, dtype: float64

# %%
df
# Out:
#           one   flag
# apple   100.0  False
# ball    200.0  False
# cerill    NaN  False
# clock   300.0   True
# dancy     NaN  False

# %%
import pandas as pd

# %%
    d = {'one' : pd.Series([100, 200, 300], index=['apple', 'ball', 'clock']), 'two' : pd.Series([111, 222, 333, 4444], index=['apple', 'ball', 'cerill', 'dancy'])}

# %%
df = pd.DataFrame(d)
print(df)
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df['one']
# Out:
# apple     100.0
# ball      200.0
# cerill      NaN
# clock     300.0
# dancy       NaN
# Name: one, dtype: float64

# %%
df['three']= df['one']*df['two']
df
# Out:
#           one     two    three
# apple   100.0   111.0  11100.0
# ball    200.0   222.0  44400.0
# cerill    NaN   333.0      NaN
# clock   300.0     NaN      NaN
# dancy     NaN  4444.0      NaN

# %%
df['flag']= df['one']>250
df
# Out:
#           one     two    three   flag
# apple   100.0   111.0  11100.0  False
# ball    200.0   222.0  44400.0  False
# cerill    NaN   333.0      NaN  False
# clock   300.0     NaN      NaN   True
# dancy     NaN  4444.0      NaN  False

# %%
three= df.pop('three')

# %%
three
# Out:
# apple     11100.0
# ball      44400.0
# cerill        NaN
# clock         NaN
# dancy         NaN
# Name: three, dtype: float64

# %%
del df['two']

# %%
df
# Out:
#           one   flag
# apple   100.0  False
# ball    200.0  False
# cerill    NaN  False
# clock   300.0   True
# dancy     NaN  False

# %%
df.insert(2, 'copy_of_one', df['one'])
df
# Out:
#           one   flag  copy_of_one
# apple   100.0  False        100.0
# ball    200.0  False        200.0
# cerill    NaN  False          NaN
# clock   300.0   True        300.0
# dancy     NaN  False          NaN

# %%
df['one_upper_half']=df['one'][:2]
df
# Out:
#           one   flag  copy_of_one  one_upper_half
# apple   100.0  False        100.0           100.0
# ball    200.0  False        200.0           200.0
# cerill    NaN  False          NaN             NaN
# clock   300.0   True        300.0             NaN
# dancy     NaN  False          NaN             NaN

# %%
df['one_upper_full']=df['one'][:4]
df
# Out:
#           one   flag  copy_of_one  one_upper_half  one_upper_full
# apple   100.0  False        100.0           100.0           100.0
# ball    200.0  False        200.0           200.0           200.0
# cerill    NaN  False          NaN             NaN             NaN
# clock   300.0   True        300.0             NaN           300.0
# dancy     NaN  False          NaN             NaN             NaN

# %%
movies=pd.read_csv('C:\ml-25m\movies.csv')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
tags=pd.read_csv('C:/ml-25m/tags.csv')

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags.head(10)
# Out:
#    userId  movieId                      tag   timestamp
# 0       3      260                  classic  1439472355
# 1       3      260                   sci-fi  1439472256
# 2       4     1732              dark comedy  1573943598
# 3       4     1732           great dialogue  1573943604
# 4       4     7569         so bad it's good  1573943455
# 5       4    44665     unreliable narrators  1573943619
# 6       4   115569                    tense  1573943077
# 7       4   115713  artificial intelligence  1573942979
# 8       4   115713            philosophical  1573943033
# 9       4   115713                    tense  1573943042

# %%
ratings=pd.read_csv('C:/ml-25m/ratings.csv')

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
# 5       1     1088     4.0  1147868495
# 6       1     1175     3.5  1147868826
# 7       1     1217     3.5  1147878326
# 8       1     1237     5.0  1147868839
# 9       1     1250     4.0  1147868414

# %%
ratings.head(10)

# %%
tags.head()
# Out:
#    userId  movieId               tag
# 0       3      260           classic
# 1       3      260            sci-fi
# 2       4     1732       dark comedy
# 3       4     1732    great dialogue
# 4       4     7569  so bad it's good

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=1093360, step=1)

# %%
ratings.head(10)
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,2000]]
# Out:
#       userId  movieId           tag
# 0          3      260       classic
# 11         4   164909        cliche
# 2000     647   164179  twist ending

# %%
tags.iloc[[0,13,2000]]
# Out:
#       userId  movieId           tag
# 0          3      260       classic
# 13         4   168250        horror
# 2000     647   164179  twist ending

# %%
tags.describe()
# Out:
#              userId       movieId
# count  1.093360e+06  1.093360e+06
# mean   6.759022e+04  5.849276e+04
# std    5.152114e+04  5.968731e+04
# min    3.000000e+00  1.000000e+00
# 25%    1.520400e+04  3.504000e+03
# 50%    6.219900e+04  4.594000e+04
# 75%    1.136420e+05  1.029030e+05
# max    1.625340e+05  2.090630e+05

# %%
tags.describe()
# Out:
# count    2.500010e+07
# mean     3.533854e+00
# std      1.060744e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings['rating'].mean()
# Out:
# 3.533854451353085

# %%
ratings.mean()
# Out:
# userId     81189.281154
# movieId    21387.981943
# rating         3.533854
# dtype: float64

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max
# Out:
# <bound method Series.max of 0           5.0
# 1           3.5
# 2           5.0
# 3           5.0
# 4           3.5
#            ...
# 25000090    4.5
# 25000091    2.5
# 25000092    2.0
# 25000093    4.0
# 25000094    5.0
# Name: rating, Length: 25000095, dtype: float64>

# %%
ratings['rating'].std()
# Out:
# 1.0607439610179747

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.004413  0.001940
# movieId -0.004413  1.000000 -0.009216
# rating   0.001940 -0.009216  1.000000

# %%
filter_1=ratings['rating']>5
filter_1.any()
# Out:
# False

# %%
filter_2=ratings['rating']>0
filter_2.all()
# Out:
# True

# %%
movies.shape
# Out:
# (62423, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
movies.isnull().any().any()
# Out:
# False

# %%
ratings.shape
# Out:
# (25000095, 3)

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
ratings.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (1093360, 3)

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
tags.isnull().any().any()
# Out:
# True

# %%
tags=tags.dropna()

# %%
tags.shape
# Out:
# (1093344, 3)

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
ratings.hist(column='rating', figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'rating'}>]], dtype=object)

# %%
ratings.barplot(column='rating', figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-115-da74a86d493e> in <module>
# ----> 1 ratings.barplot(column='rating', figsize=(15,10))
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'barplot'

# %%
import pandas as pd

# %%
    d = {'one' : pd.Series([100, 200, 300], index=['apple', 'ball', 'clock']), 'two' : pd.Series([111, 222, 333, 4444], index=['apple', 'ball', 'cerill', 'dancy'])}

# %%
df = pd.DataFrame(d)
print(df)
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
movies=pd.read_csv('C:\ml-25m\movies.csv')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
tags=pd.read_csv('C:\ml-25m\tags.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-5ce6af8cf9d9> in <module>
# ----> 1 tags=pd.read_csv('C:\ml-25m\tags.csv')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# OSError: [Errno 22] Invalid argument: 'C:\\ml-25m\tags.csv'

# %%
tags=pd.read_csv('C:/ml-25m/tags.csv')

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=1093360, step=1)

# %%
ratings=pd.read_csv('C:/ml-25m/ratings.csv')

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
# 5       1     1088     4.0  1147868495
# 6       1     1175     3.5  1147868826
# 7       1     1217     3.5  1147878326
# 8       1     1237     5.0  1147868839
# 9       1     1250     4.0  1147868414

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
# 5       1     1088     4.0  1147868495
# 6       1     1175     3.5  1147868826
# 7       1     1217     3.5  1147878326
# 8       1     1237     5.0  1147868839
# 9       1     1250     4.0  1147868414

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510
# 5       1     1088     4.0  1147868495
# 6       1     1175     3.5  1147868826
# 7       1     1217     3.5  1147878326
# 8       1     1237     5.0  1147868839
# 9       1     1250     4.0  1147868414

# %%
tags.iloc[[0,11,2000]]
# Out:
#       userId  movieId           tag   timestamp
# 0          3      260       classic  1439472355
# 11         4   164909        cliche  1573943721
# 2000     647   164179  twist ending  1505599624

# %%
tags.describe()
# Out:
#              userId       movieId     timestamp
# count  1.093360e+06  1.093360e+06  1.093360e+06
# mean   6.759022e+04  5.849276e+04  1.430115e+09
# std    5.152114e+04  5.968731e+04  1.177384e+08
# min    3.000000e+00  1.000000e+00  1.135429e+09
# 25%    1.520400e+04  3.504000e+03  1.339262e+09
# 50%    6.219900e+04  4.594000e+04  1.468929e+09
# 75%    1.136420e+05  1.029030e+05  1.527402e+09
# max    1.625340e+05  2.090630e+05  1.574317e+09

# %%
tags['tag'].head()
# Out:
# 0             classic
# 1              sci-fi
# 2         dark comedy
# 3      great dialogue
# 4    so bad it's good
# Name: tag, dtype: object

# %%
movies[['title', 'generes']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-07a8aa0891fe> in <module>
# ----> 1 movies[['title', 'generes']].head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['generes'] not in index"

# %%
movies=pd.read_csv('C:\ml-25m\movies.csv')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
movies[['title', 'genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[1000:1010]
# Out:
#       userId  movieId  rating   timestamp
# 1000       4    45517     2.5  1573939887
# 1001       4    45722     3.5  1573939645
# 1002       4    46948     2.5  1573940806
# 1003       4    46972     3.5  1573942264
# 1004       4    48780     5.0  1573938502
# 1005       4    48982     3.0  1573940905
# 1006       4    49272     3.5  1573938085
# 1007       4    49396     3.5  1573941006
# 1008       4    49649     1.0  1573940734
# 1009       4    50601     1.5  1573940778

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[:10]
# Out:
# sci-fi                8330
# atmospheric           6516
# action                5907
# comedy                5702
# surreal               5326
# based on a book       5079
# twist ending          4820
# funny                 4738
# visually appealing    4526
# dystopia              4257
# Name: tag, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
tag_counts[:10].plot(kind='pie', figsize=(15,10))
# Out:
# <AxesSubplot:ylabel='tag'>

# %%
is_highly_rated= ratings['rating']>=4.0
ratings[is_highly_rated][-5:]
# Out:
#           userId  movieId  rating   timestamp
# 25000088  162541    41566     4.0  1240952749
# 25000089  162541    45517     4.5  1240953353
# 25000090  162541    50872     4.5  1240953372
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515

# %%
is_animation=movies['genres'].str.contains('Animation')
movies[is_animation][5:15]
# Out:
#      movieId                                       title  \
# 309      313                   Swan Princess, The (1994)
# 359      364                       Lion King, The (1994)
# 387      392  Secret Adventures of Tom Thumb, The (1993)
# 545      551      Nightmare Before Christmas, The (1993)
# 551      558                      Pagemaster, The (1994)
# 580      588                              Aladdin (1992)
# 586      594      Snow White and the Seven Dwarfs (1937)
# 587      595                 Beauty and the Beast (1991)
# 588      596                            Pinocchio (1940)
# 602      610                          Heavy Metal (1981)
#
#                                               genres
# 309                               Animation|Children
# 359  Adventure|Animation|Children|Drama|Musical|IMAX
# 387                              Adventure|Animation
# 545               Animation|Children|Fantasy|Musical
# 551      Action|Adventure|Animation|Children|Fantasy
# 580      Adventure|Animation|Children|Comedy|Musical
# 586         Animation|Children|Drama|Fantasy|Musical
# 587  Animation|Children|Fantasy|Musical|Romance|IMAX
# 588               Animation|Children|Fantasy|Musical
# 602         Action|Adventure|Animation|Horror|Sci-Fi

# %%
movies[is_animation].head(15)
# Out:
#      movieId                                       title  \
# 0          1                            Toy Story (1995)
# 12        13                                Balto (1995)
# 47        48                           Pocahontas (1995)
# 236      239                       Goofy Movie, A (1995)
# 241      244                     Gumby: The Movie (1995)
# 309      313                   Swan Princess, The (1994)
# 359      364                       Lion King, The (1994)
# 387      392  Secret Adventures of Tom Thumb, The (1993)
# 545      551      Nightmare Before Christmas, The (1993)
# 551      558                      Pagemaster, The (1994)
# 580      588                              Aladdin (1992)
# 586      594      Snow White and the Seven Dwarfs (1937)
# 587      595                 Beauty and the Beast (1991)
# 588      596                            Pinocchio (1940)
# 602      610                          Heavy Metal (1981)
#
#                                               genres
# 0        Adventure|Animation|Children|Comedy|Fantasy
# 12                      Adventure|Animation|Children
# 47          Animation|Children|Drama|Musical|Romance
# 236                Animation|Children|Comedy|Romance
# 241                               Animation|Children
# 309                               Animation|Children
# 359  Adventure|Animation|Children|Drama|Musical|IMAX
# 387                              Adventure|Animation
# 545               Animation|Children|Fantasy|Musical
# 551      Action|Adventure|Animation|Children|Fantasy
# 580      Adventure|Animation|Children|Comedy|Musical
# 586         Animation|Children|Drama|Fantasy|Musical
# 587  Animation|Children|Fantasy|Musical|Romance|IMAX
# 588               Animation|Children|Fantasy|Musical
# 602         Action|Adventure|Animation|Horror|Sci-Fi

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      393068
# 1.0      776815
# 1.5      399490
# 2.0     1640868
# 2.5     1262797
# 3.0     4896928
# 3.5     3177318
# 4.0     6639798
# 4.5     2200539
# 5.0     3612474

# %%
average_rating=ratings[['movieId', 'rating']].groupby('movieId').mean()
average_rating.tail()
# Out:
#          rating
# movieId
# 209157      1.5
# 209159      3.0
# 209163      4.5
# 209169      3.0
# 209171      3.0

# %%
movie_count=ratings[['movieId', 'rating']].groupby('movieId').count()
movie_count.head()
# Out:
#          rating
# movieId
# 1         57309
# 2         24228
# 3         11804
# 4          2523
# 5         11714

# %%
movie_count=ratings[['movieId', 'rating']].groupby('movieId').count()
movie_count.tail()
# Out:
#          rating
# movieId
# 209157        1
# 209159        1
# 209163        1
# 209169        1
# 209171        1

# %%
movie_count=ratings[['movieId','userId', 'rating']].groupby('movieId').count()
movie_count.tail()
# Out:
#          userId  rating
# movieId
# 209157        1       1
# 209159        1       1
# 209163        1       1
# 209169        1       1
# 209171        1       1

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t=movies.merge(tags, on='movieId', how="inner")
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId           tag   timestamp
# 0     791         Owned  1515175493
# 1    1048  imdb top 250  1172144394
# 2    1361         Pixar  1216146311
# 3    3164         Pixar  1223304727
# 4    3164   time travel  1223304729

# %%
f=movies.merge(tags, on='movieId', how="outer")
f.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId           tag     timestamp
# 0   791.0         Owned  1.515175e+09
# 1  1048.0  imdb top 250  1.172144e+09
# 2  1361.0         Pixar  1.216146e+09
# 3  3164.0         Pixar  1.223305e+09
# 4  3164.0   time travel  1.223305e+09

# %%
t.shape
# Out:
# (1093360, 6)

# %%
f.shape
# Out:
# (1110532, 6)

# %%
avg_ratings=ratings.groupby('movieId',as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating     timestamp
# 0        1  3.893708  1.153152e+09
# 1        2  3.251527  1.122310e+09
# 2        3  3.142028  9.806023e+08
# 3        4  2.853547  9.424605e+08
# 4        5  3.058434  1.004723e+09

# %%
avg_ratings=ratings.groupby('movieId',as_index=False).mean()
del avg_ratings['userId']
avg_ratings.tail()
# Out:
#        movieId  rating     timestamp
# 59042   209157     1.5  1.574281e+09
# 59043   209159     3.0  1.574281e+09
# 59044   209163     4.5  1.574285e+09
# 59045   209169     3.0  1.574292e+09
# 59046   209171     3.0  1.574292e+09

# %%
movies_genres = movies['genres'].str.split('|', expand=True)

# %%
movies_genres[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None

# %%
movies_genres = movies['genres'].str.split('&', expand=True)

# %%
movies_genres[:10]
# Out:
#                                              0
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
tags.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp     int64
# dtype: object

# %%
average_rating = ratings[['movieId', 'rating']].groupby('movieId', as_index=False).mean()
average_rating.tail()
# Out:
#        movieId  rating
# 59042   209157     1.5
# 59043   209159     3.0
# 59044   209163     4.5
# 59045   209169     3.0
# 59046   209171     3.0

# %%
joined = movies.merge(average_rating, on='movieId', how='inner')
joined.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres    rating
# 0  Adventure|Animation|Children|Comedy|Fantasy  3.893708
# 1                   Adventure|Children|Fantasy  3.251527
# 2                               Comedy|Romance  3.142028
# 3                         Comedy|Drama|Romance  2.853547
# 4                                       Comedy  3.058434

# %%
joined.corr()
# Out:
#           movieId    rating
# movieId  1.000000 -0.093459
# rating  -0.093459  1.000000

# %%
yearly_average = joined[['year', 'rating']].groupby('year',as_index=False).mean()
yearly_average[:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-9c9305d517c0> in <module>
# ----> 1 yearly_average = joined[['year', 'rating']].groupby('year',as_index=False).mean()
#       2 yearly_average[:10]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['year'] not in index"

# %%
movies=pd.read_csv('C:\ml-25m\movies.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0b04d335c564> in <module>
# ----> 1 movies=pd.read_csv('C:\ml-25m\movies.csv')
#
# NameError: name 'pd' is not defined
